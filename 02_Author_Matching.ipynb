# %% [markdown]
# <a href="https://colab.research.google.com/github/niya-shroff/HCI-VIS-Lab-Research-Project/blob/main/02_Author_Matching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Match authors between Vispubdata and HCI-VIS datasets

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Gender in Visualization Project/HCI-VIS Data'

# %%
vispubAuthors = pd.read_csv(f'{path}/For Colab/AuthorPublication-uptoVIS2020.csv')

# %%
vispubAuthors
# Out:
#       Conference  Year                         DOI               Author  \
# 0            Vis  1990  10.1109/VISUAL.1990.146359         james helman
# 1            Vis  1990  10.1109/VISUAL.1990.146359  lambertus hesselink
# 2            Vis  1990  10.1109/VISUAL.1990.146360   gordon v. bancroft
# 3            Vis  1990  10.1109/VISUAL.1990.146360       fergus merritt
# 4            Vis  1990  10.1109/VISUAL.1990.146360         todd plessel
# ...          ...   ...                         ...                  ...
# 11569    InfoVis  2020   10.1109/TVCG.2020.3030396            huamin qu
# 11570    InfoVis  2020   10.1109/TVCG.2020.3030399         sven gedicke
# 11571    InfoVis  2020   10.1109/TVCG.2020.3030399      annika bonerath
# 11572    InfoVis  2020   10.1109/TVCG.2020.3030399  benjamin niedermann
# 11573    InfoVis  2020   10.1109/TVCG.2020.3030399   jan-henrik haunert
#
#        AuthorOrder AuthorOrderRank  CareerAge  CumPaper
# ...

# %%
biblioAuthors = pd.read_csv(f'{path}/For Colab/BiblioVIS - final.csv')

# %%
biblioAuthors[biblioAuthors['Author'] == 'petra isenberg']
# Out:
#          Author ID  Paper ID          Author                      Affiliation  \
# 4462   37591317800   4376145  petra isenberg    University of Calgary, Canada
# 5301   37591317800   5290700  petra isenberg    University of Calgary, Canada
# 5461   37591317800   5290713  petra isenberg    University of Calgary, Canada
# 5958   37591317800   5613504  petra isenberg                    INRIA, France
# 6246   37591317800   5652880  petra isenberg  Microsoft Research Limited, USA
# 6339   37591317800   6065014  petra isenberg                    INRIA, France
# 6985   37591317800   6327275  petra isenberg                    INRIA, France
# 7032   37591317800   6327229  petra isenberg                    INRIA, France
# 7129   37591317800   6327257  petra isenberg                    INRIA, France
# 7173   37591317800   6327281  petra isenberg             INRIA, Paris, France
# 7500   37591317800   6634108  petra isenberg                    INRIA, France
# ...
